# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

from src.config import *
from src.data_loader import *
from src.features import *
import networkx as nx
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Worked Example for `num_of_<edge_type>_edge_type`
#
# 1. load graph metadata
# 2. sample any individual graph
# 4. load graph dataframe(s) and manifests and explore via pandas

# %%
meta_df = get_graph_metadata(filter_nas=True, uq=0.99)

print("meta_df.shape", meta_df.shape)
meta_df.head(5)
# Out:
# meta_df.shape (1945, 9)
#                      G_pre_nodes  G_pre_edges  G_post_nodes  G_post_edges  \
# graph_id_with_label
# 10-1                      6919.0      24176.0        6796.0       23614.0
# 1000-0                    1706.0       5810.0        1707.0        5811.0
# 1001-1                    2733.0      10458.0         814.0        2853.0
# 1005-1                    7486.0      28481.0        6627.0       23157.0
# 1010b-0                   4551.0      17920.0           NaN           NaN
#
#                      G_delta_nodes  G_delta_edges     id  label  \
# graph_id_with_label
# 10-1                          60.0          224.0     10      1
# 1000-0                         6.0           10.0   1000      0
# 1001-1                       161.0          322.0   1001      1
# 1005-1                       950.0         4471.0   1005      1
# 1010b-0                        6.0           10.0  1010b      0
#
#                      edge_node_ratio
# graph_id_with_label
# 10-1                        3.494147
# 1000-0                      3.405627
# 1001-1                      3.826564
# 1005-1                      3.804569
# 1010b-0                     3.937596

# %%
sample = meta_df.sample(n=1)
sample_id = sample.index.values[0]

print("sample_id", sample_id)
sample
# Out:
# sample_id 887-1
#                      G_pre_nodes  G_pre_edges  G_post_nodes  G_post_edges  \
# graph_id_with_label
# 887-1                     3340.0      15865.0        3329.0       16246.0
#
#                      G_delta_nodes  G_delta_edges   id  label  edge_node_ratio
# graph_id_with_label
# 887-1                         19.0           56.0  887      1             4.75

# %%
df = load_df(sample_id, GraphType.PRE_INTERVENTION)

print("df.shape", df.shape)
df.head(5)
# Out:
# df.shape (15865, 46)
#   edge_source edge_target edge_args edge_script_id edge_parent  \
# 0          n1         n20
# 1          n1         n20                                  2.0
# 2          n1         n23
# 3          n1         n23
# 4          n1         n23
#
#                      edge_value edge_edge_type edge_timestamp edge_status  \
# 0                                  create node          102.0
# 1                                  insert node          120.0
# 2                                  create node          148.0
# 3  http://www.w3.org/1999/xhtml  set attribute          157.0
# 4                            de  set attribute          209.0
#
#   edge_attr_name  ... target_is_deleted target_tag_name target_url  \
# 0                 ...             False            html
# 1                 ...             False            html
# 2                 ...             False            html
# 3                 ...             False            html
# 4                 ...             False            html
#
#   target_script_id target_script_type target_text target_method target_rule  \
# 0
# 1
# 2
# 3
# 4
#
#   target_is_alt edge_response_hash
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 46 columns]

# %%
key_prefix = 'num_of_edge_type_'

df['edge_edge_type'].value_counts().to_dict()
# Out:
# {'create node': 3148,
#  'set attribute': 3025,
#  'insert node': 2864,
#  'structure': 2311,
#  'js result': 955,
#  'js call': 955,
#  'add event listener': 625,
#  'remove node': 564,
#  'event listener': 478,
#  'request start': 207,
#  'request complete': 188,
#  'storage read result': 158,
#  'read storage call': 158,
#  'remove event listener': 147,
#  'request error': 19,
#  'execute': 15,
#  'storage set': 11,
#  'resource block': 9,
#  'delete attribute': 8,
#  'filter': 8,
#  'shield': 4,
#  'storage bucket': 3,
#  'delete storage': 2,
#  'cross DOM': 2,
#  'execute from attribute': 1}

# %%
# Inspect manifest
manifest = load_manifest(sample_id)

print(manifest.keys())
print(manifest['validation'].keys())
print(manifest['result'].keys())

print("Blocked resource potentially resulting in web compat issue", manifest['validation']['url'])
# Out:
# dict_keys(['validation', 'result'])
# dict_keys(['entry', 'url', 'result', 'filterMismatches'])
# dict_keys(['snapshot', 'dump', 'screenshot'])
# Blocked resource potentially resulting in web compat issue https://www.br.de/nachrichten/verkehr/index.html

# %%
# Extract single feature for graph
from src.features import *

sample_id
df_pre = load_df(sample_id, GraphType.PRE_INTERVENTION)
df_delta = load_df(sample_id, GraphType.DELTA)
manifest = load_manifest(sample_id)

get_total_no_of_nodes(df_delta)
# Out:
# {'total_no_of_nodes': 19}

# %%
extract_general_and_specific_features(df_pre, manifest, local_scope=True)
# Out:
# {'auto_total_no_of_nodes': 11,
#  'auto_total_no_of_edges': 323,
#  'auto_no_of_unique_edge_types': 6,
#  'auto_no_of_unique_source_node_types': 5,
#  'auto_no_of_unique_target_node_type': 5,
#  'auto_no_of_edges_of_type_storage_read_result': 158,
#  'auto_no_of_edges_of_type_read_storage_call': 158,
#  'auto_no_of_edges_of_type_structure': 3,
#  'auto_no_of_edges_of_type_cross_dom': 2,
#  'auto_no_of_edges_of_type_create_node': 1,
#  'auto_no_of_edges_of_type_insert_node': 1,
#  'auto_no_of_source_nodes_of_type_cookie_jar': 158,
#  'auto_no_of_source_nodes_of_type_script': 158,
#  'auto_no_of_source_nodes_of_type_dom_root': 4,
#  'auto_no_of_source_nodes_of_type_parser': 2,
#  'auto_no_of_source_nodes_of_type_html_element': 1,
#  'auto_no_of_target_nodes_of_type_script': 158,
#  'auto_no_of_target_nodes_of_type_cookie_jar': 158,
#  'auto_no_of_target_nodes_of_type_text_node': 3,
#  'auto_no_of_target_nodes_of_type_html_element': 2,
#  'auto_no_of_target_nodes_of_type_dom_root': 2,
#  'expert_no_of_text_nodes_created': 1,
#  'expert_no_of_html_elements_created': 0,
#  'expert_no_of_dom_nodes_created_by_scripts': 0,
#  'expert_no_of_canvas_web_api_calls': 0,
#  'expert_no_of_navigator_web_api_calls': 0,
#  'expert_no_of_screen_web_api_calls': 0,
#  'expert_no_of_webgl_web_api_calls': 0,
#  'expert_no_of_cookie_jar_read_storage_calls': 158,
#  'expert_no_of_cookie_jar_set_storage_calls': 0,
#  'expert_no_of_session_storage_read_storage_calls': 0,
#  'expert_no_of_session_storage_delete_storage_calls': 0,
#  'expert_no_of_local_storage_read_storage_calls': 0,
#  'expert_no_of_local_storage_delete_storage_calls': 0,
#  'expert_sum_of_bytes_transferred_by_requests': 0,
#  'expert_no_of_resources_blocked': 0,
#  'expert_no_of_dom_related_target_nodes': 7}

# %%
# Extract all features for graph
from src.features import *

sample_id
df_pre = load_df(sample_id, GraphType.PRE_INTERVENTION)
df_delta = load_df(sample_id, GraphType.DELTA)
manifest = load_manifest(sample_id)

extract_features_for_all_graph_types_and_scopes(sample_id, df_pre, df_delta, manifest)
# Out:
# {'graph_id': '887-1',
#  'did_break': 1,
#  'global_pre_absolute_auto_total_no_of_nodes': 3335,
#  'global_pre_absolute_auto_total_no_of_edges': 15865,
#  'global_pre_absolute_auto_no_of_unique_edge_types': 25,
#  'global_pre_absolute_auto_no_of_unique_source_node_types': 13,
#  'global_pre_absolute_auto_no_of_unique_target_node_type': 16,
#  'global_pre_absolute_auto_no_of_edges_of_type_create_node': 3148,
#  'global_pre_absolute_auto_no_of_edges_of_type_set_attribute': 3025,
#  'global_pre_absolute_auto_no_of_edges_of_type_insert_node': 2864,
#  'global_pre_absolute_auto_no_of_edges_of_type_structure': 2311,
#  'global_pre_absolute_auto_no_of_edges_of_type_js_result': 955,
#  'global_pre_absolute_auto_no_of_edges_of_type_js_call': 955,
#  'global_pre_absolute_auto_no_of_edges_of_type_add_event_listener': 625,
#  'global_pre_absolute_auto_no_of_edges_of_type_remove_node': 564,
#  'global_pre_absolute_auto_no_of_edges_of_type_event_listener': 478,
#  'global_pre_absolute_auto_no_of_edges_of_type_request_start': 207,
#  'global_pre_absolute_auto_no_of_edges_of_type_request_complete': 188,
#  'global_pre_absolute_auto_no_of_edges_of_type_storage_read_result': 158,
#  'global_pre_absolute_auto_no_of_edges_of_type_read_storage_call': 158,
#  'global_pre_absolute_auto_no_of_edges_of_type_remove_event_listener': 147,
#  'global_pre_absolute_auto_no_of_edges_of_type_request_error': 19,
#  'global_pre_absolute_auto_no_of_edges_of_type_execute': 15,
#  'global_pre_absolute_auto_no_of_edges_of_type_storage_set': 11,
#  'global_pre_absolute_auto_no_of_edges_of_type_resource_block': 9,
#  'global_pre_absolute_auto_no_of_edges_of_type_delete_attribute': 8,
#  'global_pre_absolute_auto_no_of_edges_of_type_filter': 8,
#  'global_pre_absolute_auto_no_of_edges_of_type_shield': 4,
#  'global_pre_absolute_auto_no_of_edges_of_type_storage_bucket': 3,
#  'global_pre_absolute_auto_no_of_edges_of_type_delete_storage': 2,
#  'global_pre_absolute_auto_no_of_edges_of_type_cross_dom': 2,
#  'global_pre_absolute_auto_no_of_edges_of_type_execute_from_attribute': 1,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_script': 7745,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_parser': 3780,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_html_element': 2988,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_web_api': 690,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_js_builtin': 265,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_resource': 207,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_cookie_jar': 158,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_ad_filter': 9,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_ads_shield': 8,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_dom_root': 6,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_brave_shields': 4,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_storage': 3,
#  'global_pre_absolute_auto_no_of_source_nodes_of_type_extensions': 2,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_html_element': 8960,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_text_node': 3919,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_script': 1605,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_web_api': 690,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_js_builtin': 265,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_resource': 216,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_cookie_jar': 168,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_parser': 20,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_ad_filter': 8,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_dom_root': 4,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_local_storage': 3,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_session_storage': 3,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_ads_shield': 1,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_trackers_shield': 1,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_javascript_shield': 1,
#  'global_pre_absolute_auto_no_of_target_nodes_of_type_fingerprinting_shield': 1,
#  'global_pre_absolute_expert_no_of_text_nodes_created': 1253,
#  'global_pre_absolute_expert_no_of_html_elements_created': 152,
#  'global_pre_absolute_expert_no_of_dom_nodes_created_by_scripts': 683,
#  'global_pre_absolute_expert_no_of_canvas_web_api_calls': 0,
#  'global_pre_absolute_expert_no_of_navigator_web_api_calls': 21,
#  'global_pre_absolute_expert_no_of_screen_web_api_calls': 6,
#  'global_pre_absolute_expert_no_of_webgl_web_api_calls': 0,
#  'global_pre_absolute_expert_no_of_cookie_jar_read_storage_calls': 158,
#  'global_pre_absolute_expert_no_of_cookie_jar_set_storage_calls': 9,
#  'global_pre_absolute_expert_no_of_session_storage_read_storage_calls': 0,
#  'global_pre_absolute_expert_no_of_session_storage_delete_storage_calls': 1,
#  'global_pre_absolute_expert_no_of_local_storage_read_storage_calls': 0,
#  'global_pre_absolute_expert_no_of_local_storage_delete_storage_calls': 1,
#  'global_pre_absolute_expert_sum_of_bytes_transferred_by_requests': 1842273,
#  'global_pre_absolute_expert_no_of_resources_blocked': 5,
#  'global_pre_absolute_expert_no_of_dom_related_target_nodes': 12883,
#  'local_pre_absolute_auto_total_no_of_nodes': 11,
#  'local_pre_absolute_auto_total_no_of_edges': 323,
#  'local_pre_absolute_auto_no_of_unique_edge_types': 6,
#  'local_pre_absolute_auto_no_of_unique_source_node_types': 5,
#  'local_pre_absolute_auto_no_of_unique_target_node_type': 5,
#  'local_pre_absolute_auto_no_of_edges_of_type_storage_read_result': 158,
#  'local_pre_absolute_auto_no_of_edges_of_type_read_storage_call': 158,
#  'local_pre_absolute_auto_no_of_edges_of_type_structure': 3,
#  'local_pre_absolute_auto_no_of_edges_of_type_cross_dom': 2,
#  'local_pre_absolute_auto_no_of_edges_of_type_create_node': 1,
#  'local_pre_absolute_auto_no_of_edges_of_type_insert_node': 1,
#  'local_pre_absolute_auto_no_of_source_nodes_of_type_cookie_jar': 158,
#  'local_pre_absolute_auto_no_of_source_nodes_of_type_script': 158,
#  'local_pre_absolute_auto_no_of_source_nodes_of_type_dom_root': 4,
#  'local_pre_absolute_auto_no_of_source_nodes_of_type_parser': 2,
#  'local_pre_absolute_auto_no_of_source_nodes_of_type_html_element': 1,
#  'local_pre_absolute_auto_no_of_target_nodes_of_type_script': 158,
#  'local_pre_absolute_auto_no_of_target_nodes_of_type_cookie_jar': 158,
#  'local_pre_absolute_auto_no_of_target_nodes_of_type_text_node': 3,
#  'local_pre_absolute_auto_no_of_target_nodes_of_type_html_element': 2,
#  'local_pre_absolute_auto_no_of_target_nodes_of_type_dom_root': 2,
#  'local_pre_absolute_expert_no_of_text_nodes_created': 1,
#  'local_pre_absolute_expert_no_of_html_elements_created': 0,
#  'local_pre_absolute_expert_no_of_dom_nodes_created_by_scripts': 0,
#  'local_pre_absolute_expert_no_of_canvas_web_api_calls': 0,
#  'local_pre_absolute_expert_no_of_navigator_web_api_calls': 0,
#  'local_pre_absolute_expert_no_of_screen_web_api_calls': 0,
#  'local_pre_absolute_expert_no_of_webgl_web_api_calls': 0,
#  'local_pre_absolute_expert_no_of_cookie_jar_read_storage_calls': 158,
#  'local_pre_absolute_expert_no_of_cookie_jar_set_storage_calls': 0,
#  'local_pre_absolute_expert_no_of_session_storage_read_storage_calls': 0,
#  'local_pre_absolute_expert_no_of_session_storage_delete_storage_calls': 0,
#  'local_pre_absolute_expert_no_of_local_storage_read_storage_calls': 0,
#  'local_pre_absolute_expert_no_of_local_storage_delete_storage_calls': 0,
#  'local_pre_absolute_expert_sum_of_bytes_transferred_by_requests': 0,
#  'local_pre_absolute_expert_no_of_resources_blocked': 0,
#  'local_pre_absolute_expert_no_of_dom_related_target_nodes': 7,
#  'global_delta_absolute_auto_total_no_of_nodes': 19,
#  'global_delta_absolute_auto_total_no_of_edges': 56,
#  'global_delta_absolute_auto_no_of_unique_edge_types': 14,
#  'global_delta_absolute_auto_no_of_unique_source_node_types': 8,
#  'global_delta_absolute_auto_no_of_unique_target_node_type': 9,
#  'global_delta_absolute_auto_no_of_edges_of_type_create_node': 11,
#  'global_delta_absolute_auto_no_of_edges_of_type_js_result': 11,
#  'global_delta_absolute_auto_no_of_edges_of_type_js_call': 11,
#  'global_delta_absolute_auto_no_of_edges_of_type_insert_node': 10,
#  'global_delta_absolute_auto_no_of_edges_of_type_set_attribute': 4,
#  'global_delta_absolute_auto_no_of_edges_of_type_shield': 1,
#  'global_delta_absolute_auto_no_of_edges_of_type_filter': 1,
#  'global_delta_absolute_auto_no_of_edges_of_type_add_event_listener': 1,
#  'global_delta_absolute_auto_no_of_edges_of_type_remove_event_listener': 1,
#  'global_delta_absolute_auto_no_of_edges_of_type_remove_node': 1,
#  'global_delta_absolute_auto_no_of_edges_of_type_request_start': 1,
#  'global_delta_absolute_auto_no_of_edges_of_type_execute': 1,
#  'global_delta_absolute_auto_no_of_edges_of_type_request_complete': 1,
#  'global_delta_absolute_auto_no_of_edges_of_type_resource_block': 1,
#  'global_delta_absolute_auto_no_of_source_nodes_of_type_script': 39,
#  'global_delta_absolute_auto_no_of_source_nodes_of_type_web_api': 8,
#  'global_delta_absolute_auto_no_of_source_nodes_of_type_js_builtin': 3,
#  'global_delta_absolute_auto_no_of_source_nodes_of_type_html_element': 2,
#  'global_delta_absolute_auto_no_of_source_nodes_of_type_brave_shields': 1,
#  'global_delta_absolute_auto_no_of_source_nodes_of_type_ads_shield': 1,
#  'global_delta_absolute_auto_no_of_source_nodes_of_type_resource': 1,
#  'global_delta_absolute_auto_no_of_source_nodes_of_type_ad_filter': 1,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_html_element': 22,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_script': 12,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_web_api': 8,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_text_node': 6,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_js_builtin': 3,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_resource': 2,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_ads_shield': 1,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_ad_filter': 1,
#  'global_delta_absolute_auto_no_of_target_nodes_of_type_dom_root': 1,
#  'global_delta_absolute_expert_no_of_text_nodes_created': 3,
#  'global_delta_absolute_expert_no_of_html_elements_created': 0,
#  'global_delta_absolute_expert_no_of_dom_nodes_created_by_scripts': 10,
#  'global_delta_absolute_expert_no_of_canvas_web_api_calls': 0,
#  'global_delta_absolute_expert_no_of_navigator_web_api_calls': 0,
#  'global_delta_absolute_expert_no_of_screen_web_api_calls': 0,
#  'global_delta_absolute_expert_no_of_webgl_web_api_calls': 0,
#  'global_delta_absolute_expert_no_of_cookie_jar_read_storage_calls': 0,
#  'global_delta_absolute_expert_no_of_cookie_jar_set_storage_calls': 0,
#  'global_delta_absolute_expert_no_of_session_storage_read_storage_calls': 0,
#  'global_delta_absolute_expert_no_of_session_storage_delete_storage_calls': 0,
#  'global_delta_absolute_expert_no_of_local_storage_read_storage_calls': 0,
#  'global_delta_absolute_expert_no_of_local_storage_delete_storage_calls': 0,
#  'global_delta_absolute_expert_sum_of_bytes_transferred_by_requests': 126432,
#  'global_delta_absolute_expert_no_of_resources_blocked': 1,
#  'global_delta_absolute_expert_no_of_dom_related_target_nodes': 29,
#  'local_delta_absolute_auto_total_no_of_nodes': 0,
#  'local_delta_absolute_auto_total_no_of_edges': 0,
#  'local_delta_absolute_auto_no_of_unique_edge_types': 0,
#  'local_delta_absolute_auto_no_of_unique_source_node_types': 0,
#  'local_delta_absolute_auto_no_of_unique_target_node_type': 0,
#  'local_delta_absolute_expert_no_of_text_nodes_created': 0,
#  'local_delta_absolute_expert_no_of_html_elements_created': 0,
#  'local_delta_absolute_expert_no_of_dom_nodes_created_by_scripts': 0,
#  'local_delta_absolute_expert_no_of_canvas_web_api_calls': 0,
#  'local_delta_absolute_expert_no_of_navigator_web_api_calls': 0,
#  'local_delta_absolute_expert_no_of_screen_web_api_calls': 0,
#  'local_delta_absolute_expert_no_of_webgl_web_api_calls': 0,
#  'local_delta_absolute_expert_no_of_cookie_jar_read_storage_calls': 0,
#  'local_delta_absolute_expert_no_of_cookie_jar_set_storage_calls': 0,
#  'local_delta_absolute_expert_no_of_session_storage_read_storage_calls': 0,
#  'local_delta_absolute_expert_no_of_session_storage_delete_storage_calls': 0,
#  'local_delta_absolute_expert_no_of_local_storage_read_storage_calls': 0,
#  'local_delta_absolute_expert_no_of_local_storage_delete_storage_calls': 0,
#  'local_delta_absolute_expert_sum_of_bytes_transferred_by_requests': 0,
#  'local_delta_absolute_expert_no_of_resources_blocked': 0,
#  'local_delta_absolute_expert_no_of_dom_related_target_nodes': 0,
#  'global_relative_auto_no_of_edges_of_type_add_event_listener': 0.0016,
#  'global_relative_auto_no_of_edges_of_type_create_node': 0.00349428208386277,
#  'global_relative_auto_no_of_edges_of_type_cross_dom': 0.0,
#  'global_relative_auto_no_of_edges_of_type_delete_attribute': 0.0,
#  'global_relative_auto_no_of_edges_of_type_delete_storage': 0.0,
#  'global_relative_auto_no_of_edges_of_type_event_listener': 0.0,
#  'global_relative_auto_no_of_edges_of_type_execute': 0.06666666666666667,
#  'global_relative_auto_no_of_edges_of_type_execute_from_attribute': 0.0,
#  'global_relative_auto_no_of_edges_of_type_filter': 0.125,
#  'global_relative_auto_no_of_edges_of_type_insert_node': 0.0034916201117318434,
#  'global_relative_auto_no_of_edges_of_type_js_call': 0.011518324607329843,
#  'global_relative_auto_no_of_edges_of_type_js_result': 0.011518324607329843,
#  'global_relative_auto_no_of_edges_of_type_read_storage_call': 0.0,
#  'global_relative_auto_no_of_edges_of_type_remove_event_listener': 0.006802721088435374,
#  'global_relative_auto_no_of_edges_of_type_remove_node': 0.0017730496453900709,
#  'global_relative_auto_no_of_edges_of_type_request_complete': 0.005319148936170213,
#  'global_relative_auto_no_of_edges_of_type_request_error': 0.0,
#  'global_relative_auto_no_of_edges_of_type_request_start': 0.004830917874396135,
#  'global_relative_auto_no_of_edges_of_type_resource_block': 0.1111111111111111,
#  'global_relative_auto_no_of_edges_of_type_set_attribute': 0.001322314049586777,
#  'global_relative_auto_no_of_edges_of_type_shield': 0.25,
#  'global_relative_auto_no_of_edges_of_type_storage_bucket': 0.0,
#  'global_relative_auto_no_of_edges_of_type_storage_read_result': 0.0,
#  'global_relative_auto_no_of_edges_of_type_storage_set': 0.0,
#  'global_relative_auto_no_of_edges_of_type_structure': 0.0,
#  'global_relative_auto_no_of_source_nodes_of_type_ad_filter': 0.1111111111111111,
#  'global_relative_auto_no_of_source_nodes_of_type_ads_shield': 0.125,
#  'global_relative_auto_no_of_source_nodes_of_type_brave_shields': 0.25,
#  'global_relative_auto_no_of_source_nodes_of_type_cookie_jar': 0.0,
#  'global_relative_auto_no_of_source_nodes_of_type_dom_root': 0.0,
#  'global_relative_auto_no_of_source_nodes_of_type_extensions': 0.0,
#  'global_relative_auto_no_of_source_nodes_of_type_html_element': 0.0006693440428380187,
#  'global_relative_auto_no_of_source_nodes_of_type_js_builtin': 0.011320754716981131,
#  'global_relative_auto_no_of_source_nodes_of_type_parser': 0.0,
#  'global_relative_auto_no_of_source_nodes_of_type_resource': 0.004830917874396135,
#  'global_relative_auto_no_of_source_nodes_of_type_script': 0.005035506778566817,
#  'global_relative_auto_no_of_source_nodes_of_type_storage': 0.0,
#  'global_relative_auto_no_of_source_nodes_of_type_web_api': 0.011594202898550725,
#  'global_relative_auto_no_of_target_nodes_of_type_ad_filter': 0.125,
#  'global_relative_auto_no_of_target_nodes_of_type_ads_shield': 1.0,
#  'global_relative_auto_no_of_target_nodes_of_type_cookie_jar': 0.0,
#  'global_relative_auto_no_of_target_nodes_of_type_dom_root': 0.25,
#  'global_relative_auto_no_of_target_nodes_of_type_fingerprinting_shield': 0.0,
#  'global_relative_auto_no_of_target_nodes_of_type_html_element': 0.002455357142857143,
#  'global_relative_auto_no_of_target_nodes_of_type_javascript_shield': 0.0,
#  'global_relative_auto_no_of_target_nodes_of_type_js_builtin': 0.011320754716981131,
#  'global_relative_auto_no_of_target_nodes_of_type_local_storage': 0.0,
#  'global_relative_auto_no_of_target_nodes_of_type_parser': 0.0,
#  'global_relative_auto_no_of_target_nodes_of_type_resource': 0.009259259259259259,
#  'global_relative_auto_no_of_target_nodes_of_type_script': 0.007476635514018692,
#  'global_relative_auto_no_of_target_nodes_of_type_session_storage': 0.0,
#  'global_relative_auto_no_of_target_nodes_of_type_text_node': 0.0015310028068384791,
#  'global_relative_auto_no_of_target_nodes_of_type_trackers_shield': 0.0,
#  'global_relative_auto_no_of_target_nodes_of_type_web_api': 0.011594202898550725,
#  'global_relative_auto_no_of_unique_edge_types': 0.56,
#  'global_relative_auto_no_of_unique_source_node_types': 0.6153846153846154,
#  'global_relative_auto_no_of_unique_target_node_type': 0.5625,
#  'global_relative_auto_total_no_of_edges': 0.003529782540182792,
#  'global_relative_auto_total_no_of_nodes': 0.005697151424287856,
#  'global_relative_expert_no_of_canvas_web_api_calls': 0.0,
#  'global_relative_expert_no_of_cookie_jar_read_storage_calls': 0.0,
#  'global_relative_expert_no_of_cookie_jar_set_storage_calls': 0.0,
#  'global_relative_expert_no_of_dom_nodes_created_by_scripts': 0.014641288433382138,
#  'global_relative_expert_no_of_dom_related_target_nodes': 0.0022510284871536134,
#  'global_relative_expert_no_of_html_elements_created': 0.0,
#  'global_relative_expert_no_of_local_storage_delete_storage_calls': 0.0,
#  'global_relative_expert_no_of_local_storage_read_storage_calls': 0.0,
#  'global_relative_expert_no_of_navigator_web_api_calls': 0.0,
#  'global_relative_expert_no_of_resources_blocked': 0.2,
#  'global_relative_expert_no_of_screen_web_api_calls': 0.0,
#  'global_relative_expert_no_of_session_storage_delete_storage_calls': 0.0,
#  'global_relative_expert_no_of_session_storage_read_storage_calls': 0.0,
#  'global_relative_expert_no_of_text_nodes_created': 0.0023942537909018356,
#  'global_relative_expert_no_of_webgl_web_api_calls': 0.0,
#  'global_relative_expert_sum_of_bytes_transferred_by_requests': 0.06862826519196666,
#  'local_relative_auto_no_of_edges_of_type_create_node': 0.0,
#  'local_relative_auto_no_of_edges_of_type_cross_dom': 0.0,
#  'local_relative_auto_no_of_edges_of_type_insert_node': 0.0,
#  'local_relative_auto_no_of_edges_of_type_read_storage_call': 0.0,
#  'local_relative_auto_no_of_edges_of_type_storage_read_result': 0.0,
#  'local_relative_auto_no_of_edges_of_type_structure': 0.0,
#  'local_relative_auto_no_of_source_nodes_of_type_cookie_jar': 0.0,
#  'local_relative_auto_no_of_source_nodes_of_type_dom_root': 0.0,
#  'local_relative_auto_no_of_source_nodes_of_type_html_element': 0.0,
#  'local_relative_auto_no_of_source_nodes_of_type_parser': 0.0,
#  'local_relative_auto_no_of_source_nodes_of_type_script': 0.0,
#  'local_relative_auto_no_of_target_nodes_of_type_cookie_jar': 0.0,
#  'local_relative_auto_no_of_target_nodes_of_type_dom_root': 0.0,
#  'local_relative_auto_no_of_target_nodes_of_type_html_element': 0.0,
#  'local_relative_auto_no_of_target_nodes_of_type_script': 0.0,
#  'local_relative_auto_no_of_target_nodes_of_type_text_node': 0.0,
#  'local_relative_auto_no_of_unique_edge_types': 0.0,
#  'local_relative_auto_no_of_unique_source_node_types': 0.0,
#  'local_relative_auto_no_of_unique_target_node_type': 0.0,
#  'local_relative_auto_total_no_of_edges': 0.0,
#  'local_relative_auto_total_no_of_nodes': 0.0,
#  'local_relative_expert_no_of_canvas_web_api_calls': 0.0,
#  'local_relative_expert_no_of_cookie_jar_read_storage_calls': 0.0,
#  'local_relative_expert_no_of_cookie_jar_set_storage_calls': 0.0,
#  'local_relative_expert_no_of_dom_nodes_created_by_scripts': 0.0,
#  'local_relative_expert_no_of_dom_related_target_nodes': 0.0,
#  'local_relative_expert_no_of_html_elements_created': 0.0,
#  'local_relative_expert_no_of_local_storage_delete_storage_calls': 0.0,
#  'local_relative_expert_no_of_local_storage_read_storage_calls': 0.0,
#  'local_relative_expert_no_of_navigator_web_api_calls': 0.0,
#  'local_relative_expert_no_of_resources_blocked': 0.0,
#  'local_relative_expert_no_of_screen_web_api_calls': 0.0,
#  'local_relative_expert_no_of_session_storage_delete_storage_calls': 0.0,
#  'local_relative_expert_no_of_session_storage_read_storage_calls': 0.0,
#  'local_relative_expert_no_of_text_nodes_created': 0.0,
#  'local_relative_expert_no_of_webgl_web_api_calls': 0.0,
#  'local_relative_expert_sum_of_bytes_transferred_by_requests': 0.0}
